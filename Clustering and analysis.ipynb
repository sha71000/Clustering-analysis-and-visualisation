# %% [markdown]
# # Clustering and Cluster Analysis

# %% [markdown]
#  The number of appropriate clusters for Kmeans clustering was found to be 10. This section deals with the visualisation of the clusters. Some of the clusters are also analysed.

# %%
import pandas as pd
df=pd.read_csv('toronto.csv')
df=df.drop('Unnamed: 0',1)
df
# Out:
#    Postal Code           Borough                                 Neighborhood  \
# 0          M3A        North York                                    Parkwoods
# 1          M4A        North York                             Victoria Village
# 2          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3          M6A        North York             Lawrence Manor, Lawrence Heights
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# ..         ...               ...                                          ...
# 94         M1N       Scarborough                                  Birch Cliff
# 95         M5R   Central Toronto                                    Davenport
# 96         M9N              York                            York South-Weston
# 97         M3B        North York                              Edwards Gardens
# 98         M4C         East York                             Toronto Danforth
#
#      latitude  longitude  Cluster Label      1st Most Common Venue  \
# 0   43.758800 -79.320197              2                Coffee Shop
# 1   43.732658 -79.311189              5  Middle Eastern Restaurant
# 2   43.660706 -79.360457              1                Coffee Shop
# 3   43.722079 -79.437507              1                Coffee Shop
# 4   43.659659 -79.390340              0                Coffee Shop
# ..        ...        ...            ...                        ...
# 94  43.691805 -79.264494              1                       Park
# 95  43.671545 -79.448322              1                       Café
# 96  43.684466 -79.498818              8                Pizza Place
# 97  43.731442 -79.358380              6               Intersection
# 98  43.678944 -79.344860              1           Greek Restaurant
#
#    2nd Most Common Venue     3rd Most Common Venue 4th Most Common Venue  \
# 0            Pizza Place               Supermarket           Gas Station
# 1     Chinese Restaurant  Mediterranean Restaurant       Thai Restaurant
# 2             Restaurant                    Bakery                  Café
# 3          Grocery Store               Pizza Place  Fast Food Restaurant
# 4    Japanese Restaurant                      Park      Sushi Restaurant
# ..                   ...                       ...                   ...
# 94       Thai Restaurant                Restaurant       College Stadium
# 95    Italian Restaurant               Coffee Shop                  Park
# 96                  Park               Coffee Shop      Asian Restaurant
# 97      Botanical Garden             Grocery Store                  Park
# 98                  Café               Coffee Shop    Italian Restaurant
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Discount Store              Pharmacy  Fast Food Restaurant
# 1   Thrift / Vintage Store     French Restaurant          Intersection
# 2                     Park       Thai Restaurant                   Pub
# 3               Bagel Shop              Pharmacy                  Bank
# 4              Art Gallery    Mexican Restaurant      Ramen Restaurant
# ..                     ...                   ...                   ...
# 94                   Diner                  Café                   Gym
# 95                  Bakery      Sushi Restaurant  Brazilian Restaurant
# 96             Supermarket              Bus Line            Restaurant
# 97             Coffee Shop        Sandwich Place       Bubble Tea Shop
# 98                    Park            Restaurant             Bookstore
#
#    8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0         Breakfast Spot           Liquor Store                   Café
# 1       Asian Restaurant      Indian Restaurant               Bus Line
# 2              Gastropub         Breakfast Spot                  Diner
# 3               Bus Stop         Discount Store       Sushi Restaurant
# 4                   Café           Dessert Shop           Burger Joint
# ..                   ...                    ...                    ...
# 94          Skating Rink  General Entertainment       Doner Restaurant
# 95                   Bar                   Bank  Portuguese Restaurant
# 96           Golf Course         Massage Studio   Fast Food Restaurant
# 97               Stables        Fireworks Store             Donut Shop
# 98           Pizza Place                   Bank   Fast Food Restaurant
#
# [99 rows x 16 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium
import numpy as np

# %%
map_clusters = folium.Map(location=[43.6534817, -79.3839347], zoom_start=11)

# set color scheme for the clusters
x = np.arange(10)
ys = [i + x + (i*x)**2 for i in range(10)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]



markers_colors = []
for lat, lon, poi, cluster in zip(df['latitude'], df['longitude'], df['Neighborhood'], df['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Examining Clusters

# %% [markdown]
# # Cluster 0 Analysis

# %% [markdown]
# Coffee shops cafes and Japanese/sushi
# restaurants seem to be the most popular venues here. Whereas Breweries are a rare sight.  We will return neighbourhoods that do not have

# %%
cluster0=df.loc[df['Cluster Label'] == 0, df.columns[list(range(0, df.shape[1]))]]
cluster0.head()
# Out:
#    Postal Code           Borough                                 Neighborhood  \
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7          M3B        North York                                    Don Mills
# 9          M5B  Downtown Toronto                     Garden District, Ryerson
# 13         M3C        North York                                    Don Mills
# 15         M5C  Downtown Toronto                               St. James Town
#
#      latitude  longitude  Cluster Label 1st Most Common Venue  \
# 4   43.659659 -79.390340              0           Coffee Shop
# 7   43.775347 -79.345944              0        Clothing Store
# 9   43.656500 -79.377114              0           Coffee Shop
# 13  43.775347 -79.345944              0        Clothing Store
# 15  43.669403 -79.372704              0           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4    Japanese Restaurant                  Park      Sushi Restaurant
# 7            Coffee Shop  Fast Food Restaurant        Baseball Field
# 9                   Café             Gastropub   Japanese Restaurant
# 13           Coffee Shop  Fast Food Restaurant        Baseball Field
# 15            Restaurant   Japanese Restaurant                  Café
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 4            Art Gallery    Mexican Restaurant      Ramen Restaurant
# 7             Restaurant   Japanese Restaurant                  Bank
# 9     Italian Restaurant                 Hotel      Ramen Restaurant
# 13            Restaurant   Japanese Restaurant                  Bank
# 15               Gay Bar                 Diner         Grocery Store
#
#    8th Most Common Venue 9th Most Common Venue     10th Most Common Venue
# 4                   Café          Dessert Shop               Burger Joint
# 7              Juice Bar   Sporting Goods Shop                 Food Court
# 9             Poke Place                 Plaza  Middle Eastern Restaurant
# 13             Juice Bar   Sporting Goods Shop                 Food Court
# 15             Gastropub       Thai Restaurant                        Pub

# %%
s=cluster0.apply(lambda x: x.mode()).iloc[0,6:11]
s
# Out:
# 1st Most Common Venue            Coffee Shop
# 2nd Most Common Venue                   Café
# 3rd Most Common Venue             Restaurant
# 4th Most Common Venue    Japanese Restaurant
# 5th Most Common Venue             Restaurant
# Name: 0, dtype: object

# %% [markdown]
# Cluster 0 seems to be a home to a number of restarants

# %%
cluster0['3rd Most Common Venue'].value_counts()[:5]
# Out:
# Restaurant              9
# Café                    5
# Fast Food Restaurant    3
# Park                    2
# Hotel                   2
# Name: 3rd Most Common Venue, dtype: int64

# %%
cluster0['2nd Most Common Venue'].value_counts()[:5]
# Out:
# Café              11
# Coffee Shop        6
# Bar                3
# Hotel              3
# Clothing Store     2
# Name: 2nd Most Common Venue, dtype: int64

# %%
cluster0['4th Most Common Venue'].value_counts()[:5]
# Out:
# Japanese Restaurant    5
# Gastropub              3
# Bar                    2
# Park                   2
# Baseball Field         2
# Name: 4th Most Common Venue, dtype: int64

# %% [markdown]
# # Cluster 0 Conclusion

# %% [markdown]
#  Cluster 0 is defined by the amount of Restaurants, Coffee shops, Fast food and Bars. Almost all of Downtown Toronto Neighborhoods belong to this cluster, which makes sense.

# %% [markdown]
# # Cluster 1 Analysis

# %%
cluster1=df.loc[df['Cluster Label'] == 1, df.columns[list(range(0, df.shape[1]))]]
cluster1.head()
# Out:
#    Postal Code           Borough                             Neighborhood  \
# 2          M5A  Downtown Toronto                Regent Park, Harbourfront
# 3          M6A        North York         Lawrence Manor, Lawrence Heights
# 5          M9A         Etobicoke  Islington Avenue, Humber Valley Village
# 14         M4C         East York                         Woodbine Heights
# 20         M4G         East York                                  Leaside
#
#      latitude  longitude  Cluster Label 1st Most Common Venue  \
# 2   43.660706 -79.360457              1           Coffee Shop
# 3   43.722079 -79.437507              1           Coffee Shop
# 5   43.679484 -79.538909              1                  Bank
# 14  43.699930 -79.319132              1           Pizza Place
# 20  43.704798 -79.368090              1                Bakery
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2             Restaurant                Bakery                  Café
# 3          Grocery Store           Pizza Place  Fast Food Restaurant
# 5            Coffee Shop     Electronics Store            Beer Store
# 14              Pharmacy                  Park       Thai Restaurant
# 20         Grocery Store           Coffee Shop            Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2                   Park       Thai Restaurant                   Pub
# 3             Bagel Shop              Pharmacy                  Bank
# 5          Shopping Mall           Golf Course                  Café
# 14                   Pub                   Spa          Skating Rink
# 20      Sushi Restaurant   Sporting Goods Shop       Thai Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 2              Gastropub        Breakfast Spot                  Diner
# 3               Bus Stop        Discount Store       Sushi Restaurant
# 5           Liquor Store         Grocery Store         Sandwich Place
# 14        Breakfast Spot          Liquor Store                   Café
# 20     Indian Restaurant        Sandwich Place             Baby Store

# %% [markdown]
# Some of the popular venues by count:

# %%
s=cluster1.apply(lambda x: x.mode()).iloc[0,6:11]
s
# Out:
# 1st Most Common Venue           Coffee Shop
# 2nd Most Common Venue    Italian Restaurant
# 3rd Most Common Venue                  Park
# 4th Most Common Venue                  Park
# 5th Most Common Venue      Sushi Restaurant
# Name: 0, dtype: object

# %%
cluster1['5th Most Common Venue'].value_counts()[:5]
# Out:
# Sushi Restaurant      5
# Italian Restaurant    2
# Park                  2
# Bank                  2
# Café                  2
# Name: 5th Most Common Venue, dtype: int64

# %%
cluster1['2nd Most Common Venue'].value_counts()[:5]
# Out:
# Italian Restaurant    6
# Coffee Shop           5
# Bank                  3
# Café                  3
# Pizza Place           3
# Name: 2nd Most Common Venue, dtype: int64

# %%
cluster1['1st Most Common Venue'].value_counts()[:5]
# Out:
# Coffee Shop          17
# Park                  3
# Café                  2
# Pub                   1
# Indian Restaurant     1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# # Cluster 1 Conclusion

# %% [markdown]
# As we can see coffee shops and Italian/Sushi Restarants are the defining feature of this cluster on neighborhoods

# %% [markdown]
# # Cluster 8 Analysis

# %%
cluster8=df.loc[df['Cluster Label'] == 8, df.columns[list(range(0, df.shape[1]))]]
cluster8
# Out:
#    Postal Code      Borough  \
# 6          M1B  Scarborough
# 8          M4B    East York
# 10         M6B   North York
# 11         M9B    Etobicoke
# 12         M1C  Scarborough
# 16         M9C    Etobicoke
# 17         M1E  Scarborough
# 24         M2H   North York
# 43         M3L   North York
# 47         M1M  Scarborough
# 57         M9N         York
# 63         M9P    Etobicoke
# 96         M9N         York
#
#                                          Neighborhood   latitude  longitude  \
# 6                                      Malvern, Rouge  43.809196 -79.221701
# 8                     Parkview Hill, Woodbine Gardens  43.706298 -79.321907
# 10                                          Glencairn  43.708712 -79.440685
# 11  West Deane Park, Princess Gardens, Martin Grov...  43.663199 -79.568568
# 12             Rouge Hill, Port Union, Highland Creek  43.780271 -79.130499
# 16  Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.662273 -79.576516
# 17                  Guildwood, Morningside, West Hill  43.755225 -79.198229
# 24                                  Hillcrest Village  43.799664 -79.365019
# 43                                 Jane Sheppard mall  43.740283 -79.512220
# 47    Cliffside, Cliffcrest, Scarborough Village West  43.711170 -79.248177
# 57                                             Weston  43.700161 -79.516247
# 63                                          Westmount  43.693640 -79.521043
# 96                                  York South-Weston  43.684466 -79.498818
#
#     Cluster Label 1st Most Common Venue      2nd Most Common Venue  \
# 6               8                  Park       Fast Food Restaurant
# 8               8            Playground                   Pharmacy
# 10              8         Grocery Store                Pizza Place
# 11              8                  Park          Convenience Store
# 12              8                  Park               Liquor Store
# 16              8     Convenience Store                 Beer Store
# 17              8         Grocery Store                       Park
# 24              8                  Park         Chinese Restaurant
# 43              8                  Park                Coffee Shop
# 47              8                  Park                Coffee Shop
# 57              8         Train Station                Coffee Shop
# 63              8           Pizza Place  Middle Eastern Restaurant
# 96              8           Pizza Place                       Park
#
#           3rd Most Common Venue        4th Most Common Venue  \
# 6                   Pizza Place                     Pharmacy
# 8                          Park                 Skating Rink
# 10                  Coffee Shop             Asian Restaurant
# 11                     Pharmacy  Eastern European Restaurant
# 12                Train Station                          Gym
# 16  Eastern European Restaurant            Electronics Store
# 17                Train Station                        Hotel
# 24                         Bank                Grocery Store
# 43         Gym / Fitness Center                Moving Target
# 47                   Sports Bar             Sushi Restaurant
# 57                         Park            Convenience Store
# 63                Train Station                         Bank
# 96                  Coffee Shop             Asian Restaurant
#
#         5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 6               Grocery Store        Sandwich Place             Restaurant
# 8                 Pizza Place        Breakfast Spot   Fast Food Restaurant
# 10                 Shoe Store   Rental Car Location    Japanese Restaurant
# 11          Electronics Store          Skating Rink             Beer Store
# 12                 Beer Store   Japanese Restaurant            Coffee Shop
# 16         Chinese Restaurant                  Park            Coffee Shop
# 17           Storage Facility        Baseball Field            Art Gallery
# 24                Pizza Place         Shopping Mall            Supermarket
# 43                Pizza Place         Shopping Mall  Vietnamese Restaurant
# 47                      Beach        Sandwich Place         Breakfast Spot
# 57  Middle Eastern Restaurant          Soccer Field           Skating Rink
# 63                Gas Station   Fried Chicken Joint     Chinese Restaurant
# 96                Supermarket              Bus Line             Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 6        Bubble Tea Shop    Salon / Barbershop           Skating Rink
# 8              Pet Store                  Bank     Rock Climbing Spot
# 10                Bakery                 Trail                    Pub
# 11                Bakery          Home Service   Fast Food Restaurant
# 12             Pet Store  Fast Food Restaurant            Pizza Place
# 16                   Pub           Pizza Place    Filipino Restaurant
# 17           Coffee Shop        Sandwich Place          Moving Target
# 24   Szechuan Restaurant        Sandwich Place      Korean Restaurant
# 43                  Bank           Yoga Studio     Dongbei Restaurant
# 47         Train Station         Grocery Store      Fish & Chips Shop
# 57   Fried Chicken Joint            Laundromat         Sandwich Place
# 63            Restaurant                Bakery             Laundromat
# 96           Golf Course        Massage Studio   Fast Food Restaurant

# %%
s=cluster8.apply(lambda x: x.mode()).iloc[0,6:11]
s
# Out:
# 1st Most Common Venue                Park
# 2nd Most Common Venue         Coffee Shop
# 3rd Most Common Venue       Train Station
# 4th Most Common Venue    Asian Restaurant
# 5th Most Common Venue         Pizza Place
# Name: 0, dtype: object

# %%
cluster8['5th Most Common Venue'].value_counts()[:5]
# Out:
# Pizza Place                  3
# Middle Eastern Restaurant    1
# Gas Station                  1
# Storage Facility             1
# Supermarket                  1
# Name: 5th Most Common Venue, dtype: int64

# %%
cluster8['1st Most Common Venue'].value_counts()[:5]
# Out:
# Park                 6
# Grocery Store        2
# Pizza Place          2
# Playground           1
# Convenience Store    1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# # Cluster 8 Conclusion

# %% [markdown]
# Cluster 8 has an abundance of Parks and Pizza places

# %% [markdown]
# # Cluster 2 Analysis

# %%
cluster2=df.loc[df['Cluster Label'] == 2, df.columns[list(range(0, df.shape[1]))]]
cluster2
# Out:
#    Postal Code      Borough                                 Neighborhood  \
# 0          M3A   North York                                    Parkwoods
# 19         M1G  Scarborough                                       Woburn
# 23         M1H  Scarborough                                    Cedarbrae
# 29         M1J  Scarborough                          Scarborough Village
# 31         M3J   North York              Northwood Park, York University
# 35         M1K  Scarborough  Kennedy Park, Ionview, East Birchmount Park
# 53         M3N   North York                               Jane and Finch
# 90         M9M   North York                       Pelmo park, Humbermede
#
#      latitude  longitude  Cluster Label  1st Most Common Venue  \
# 0   43.758800 -79.320197              2            Coffee Shop
# 19  43.759824 -79.225291              2   Fast Food Restaurant
# 23  43.756467 -79.226692              2   Fast Food Restaurant
# 29  43.743742 -79.211632              2            Coffee Shop
# 31  43.754135 -79.504480              2            Coffee Shop
# 35  43.724878 -79.253969              2   Fast Food Restaurant
# 53  43.757253 -79.517697              2                  Hotel
# 90  43.710801 -79.510631              2  Vietnamese Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Pizza Place           Supermarket           Gas Station
# 19           Pizza Place                  Park        Sandwich Place
# 23         Grocery Store           Pizza Place        Sandwich Place
# 29               Theater  Fast Food Restaurant                   Pub
# 31  Caribbean Restaurant            Beer Store         Shopping Mall
# 35            Sports Bar         Train Station     Convenience Store
# 53         Grocery Store  Fast Food Restaurant           Pizza Place
# 90    Mexican Restaurant           Gas Station     Convenience Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Discount Store              Pharmacy  Fast Food Restaurant
# 19        Discount Store      Department Store           Coffee Shop
# 23        Discount Store                 Diner           Coffee Shop
# 29         Grocery Store                   Gym            Beer Store
# 31           Gas Station           Pizza Place  Fast Food Restaurant
# 35           Pizza Place   Sporting Goods Shop        Discount Store
# 53        Discount Store           Coffee Shop               Theater
# 90  Fast Food Restaurant              Pharmacy      Asian Restaurant
#
#      8th Most Common Venue  9th Most Common Venue  10th Most Common Venue
# 0           Breakfast Spot           Liquor Store                    Café
# 19           Grocery Store                   Bank        Czech Restaurant
# 23                    Bank  Vietnamese Restaurant  Thrift / Vintage Store
# 29          Discount Store                Butcher           Big Box Store
# 31   Vietnamese Restaurant               Pharmacy     Fried Chicken Joint
# 35           Grocery Store     Chinese Restaurant        Asian Restaurant
# 53      Falafel Restaurant           Liquor Store     Fried Chicken Joint
# 90  Furniture / Home Store   Caribbean Restaurant                    Bank

# %%
s=cluster2.apply(lambda x: x.mode()).iloc[0,6:11]
s
# Out:
# 1st Most Common Venue             Coffee Shop
# 2nd Most Common Venue           Grocery Store
# 3rd Most Common Venue    Fast Food Restaurant
# 4th Most Common Venue       Convenience Store
# 5th Most Common Venue          Discount Store
# Name: 0, dtype: object

# %%
cluster2['1st Most Common Venue'].value_counts()[:5]
# Out:
# Fast Food Restaurant     3
# Coffee Shop              3
# Hotel                    1
# Vietnamese Restaurant    1
# Name: 1st Most Common Venue, dtype: int64

# %%
cluster2['2nd Most Common Venue'].value_counts()[:5]
# Out:
# Grocery Store         2
# Pizza Place           2
# Theater               1
# Mexican Restaurant    1
# Sports Bar            1
# Name: 2nd Most Common Venue, dtype: int64

# %%
cluster2['3rd Most Common Venue'].value_counts()[:5]
# Out:
# Fast Food Restaurant    2
# Park                    1
# Train Station           1
# Gas Station             1
# Supermarket             1
# Name: 3rd Most Common Venue, dtype: int64

# %%
cluster2['4th Most Common Venue'].value_counts()[:5]
# Out:
# Sandwich Place       2
# Convenience Store    2
# Pub                  1
# Shopping Mall        1
# Gas Station          1
# Name: 4th Most Common Venue, dtype: int64

# %%
cluster2['5th Most Common Venue'].value_counts()[:5]
# Out:
# Discount Store          4
# Fast Food Restaurant    1
# Grocery Store           1
# Pizza Place             1
# Gas Station             1
# Name: 5th Most Common Venue, dtype: int64

# %% [markdown]
# # Cluster 2 Conclusion

# %% [markdown]
# Cluster 2 neighborhoods have plenty of Discount stores/Grocery stores, fast food/sandwich places, which is why they are in the same cluster
