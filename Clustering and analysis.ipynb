# %%
import pandas as pd
df=pd.read_csv('toronto.csv')
df=df.drop('Unnamed: 0',1)
df
# Out:
#    Postal Code           Borough                                 Neighborhood  \
# 0          M3A        North York                                    Parkwoods
# 1          M4A        North York                             Victoria Village
# 2          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3          M6A        North York             Lawrence Manor, Lawrence Heights
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# ..         ...               ...                                          ...
# 94         M1N       Scarborough                                  Birch Cliff
# 95         M5R   Central Toronto                                    Davenport
# 96         M9N              York                            York South-Weston
# 97         M3B        North York                              Edwards Gardens
# 98         M4C         East York                             Toronto Danforth
#
#      latitude  longitude  Cluster Label      1st Most Common Venue  \
# 0   43.758800 -79.320197              2                Coffee Shop
# 1   43.732658 -79.311189              5  Middle Eastern Restaurant
# 2   43.660706 -79.360457              1                Coffee Shop
# 3   43.722079 -79.437507              1                Coffee Shop
# 4   43.659659 -79.390340              0                Coffee Shop
# ..        ...        ...            ...                        ...
# 94  43.691805 -79.264494              1                       Park
# 95  43.671545 -79.448322              1                       Café
# 96  43.684466 -79.498818              8                Pizza Place
# 97  43.731442 -79.358380              6               Intersection
# 98  43.678944 -79.344860              1           Greek Restaurant
#
#    2nd Most Common Venue     3rd Most Common Venue 4th Most Common Venue  \
# 0            Pizza Place               Supermarket           Gas Station
# 1     Chinese Restaurant  Mediterranean Restaurant       Thai Restaurant
# 2             Restaurant                    Bakery                  Café
# 3          Grocery Store               Pizza Place  Fast Food Restaurant
# 4    Japanese Restaurant                      Park      Sushi Restaurant
# ..                   ...                       ...                   ...
# 94       Thai Restaurant                Restaurant       College Stadium
# 95    Italian Restaurant               Coffee Shop                  Park
# 96                  Park               Coffee Shop      Asian Restaurant
# 97      Botanical Garden             Grocery Store                  Park
# 98                  Café               Coffee Shop    Italian Restaurant
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Discount Store              Pharmacy  Fast Food Restaurant
# 1   Thrift / Vintage Store     French Restaurant          Intersection
# 2                     Park       Thai Restaurant                   Pub
# 3               Bagel Shop              Pharmacy                  Bank
# 4              Art Gallery    Mexican Restaurant      Ramen Restaurant
# ..                     ...                   ...                   ...
# 94                   Diner                  Café                   Gym
# 95                  Bakery      Sushi Restaurant  Brazilian Restaurant
# 96             Supermarket              Bus Line            Restaurant
# 97             Coffee Shop        Sandwich Place       Bubble Tea Shop
# 98                    Park            Restaurant             Bookstore
#
#    8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0         Breakfast Spot           Liquor Store                   Café
# 1       Asian Restaurant      Indian Restaurant               Bus Line
# 2              Gastropub         Breakfast Spot                  Diner
# 3               Bus Stop         Discount Store       Sushi Restaurant
# 4                   Café           Dessert Shop           Burger Joint
# ..                   ...                    ...                    ...
# 94          Skating Rink  General Entertainment       Doner Restaurant
# 95                   Bar                   Bank  Portuguese Restaurant
# 96           Golf Course         Massage Studio   Fast Food Restaurant
# 97               Stables        Fireworks Store             Donut Shop
# 98           Pizza Place                   Bank   Fast Food Restaurant
#
# [99 rows x 16 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium
import numpy as np

# %%
map_clusters = folium.Map(location=[43.6534817, -79.3839347], zoom_start=11)

# set color scheme for the clusters
x = np.arange(10)
ys = [i + x + (i*x)**2 for i in range(10)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]



markers_colors = []
for lat, lon, poi, cluster in zip(df['latitude'], df['longitude'], df['Neighborhood'], df['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Examining Clusters

# %% [markdown]
# Let us examine Cluster 0. Coffee shops cafes and Japanese/sushi
# restaurants seem to be the most popular venues here. Whereas Breweries are a rare sight.  We will return neighbourhoods that do not have

# %%
cluster0=df.loc[df['Cluster Label'] == 0, df.columns[list(range(0, df.shape[1]))]]
cluster0
# Out:
#    Postal Code           Borough  \
# 4          M7A  Downtown Toronto
# 7          M3B        North York
# 9          M5B  Downtown Toronto
# 13         M3C        North York
# 15         M5C  Downtown Toronto
# 18         M5E  Downtown Toronto
# 21         M5G  Downtown Toronto
# 22         M6G  Downtown Toronto
# 27         M5H  Downtown Toronto
# 28         M6H      West Toronto
# 30         M2J        North York
# 32         M4J         East York
# 33         M5J  Downtown Toronto
# 34         M6J      West Toronto
# 36         M2K        North York
# 39         M5K  Downtown Toronto
# 40         M6K      West Toronto
# 41         M1L       Scarborough
# 42         M2L        North York
# 44         M5L  Downtown Toronto
# 45         M6L        North York
# 50         M4M      East Toronto
# 66         M4R   Central Toronto
# 67         M5R   Central Toronto
# 68         M6R      West Toronto
# 71         M5S  Downtown Toronto
# 75         M5T  Downtown Toronto
# 78         M5V  Downtown Toronto
# 83         M9W         Etobicoke
# 85         M4X  Downtown Toronto
# 86         M5X  Downtown Toronto
# 88         M4Y  Downtown Toronto
#
#                                          Neighborhood   latitude  longitude  \
# 4         Queen's Park, Ontario Provincial Government  43.659659 -79.390340
# 7                                           Don Mills  43.775347 -79.345944
# 9                            Garden District, Ryerson  43.656500 -79.377114
# 13                                          Don Mills  43.775347 -79.345944
# 15                                     St. James Town  43.669403 -79.372704
# 18                                        Berczy Park  43.647984 -79.375396
# 21                                 Central Bay Street  43.656119 -79.384670
# 22                                           Christie  43.664111 -79.418405
# 27                           Richmond, Adelaide, King  43.648587 -79.391373
# 28                       Dufferin, Dovercourt Village  43.660202 -79.435719
# 30                       Fairview, Henry Farm, Oriole  43.777758 -79.344294
# 32      East Toronto, Broadview North (Old East York)  43.653482 -79.383935
# 33  Harbourfront East, Union Station, Toronto Islands  43.640080 -79.380150
# 34                           Little Portugal, Trinity  43.647413 -79.431116
# 36                                    Bayview Village  43.769197 -79.376662
# 39           Toronto Dominion Centre, Design Exchange  43.647377 -79.381372
# 40       Brockton, Parkdale Village, Exhibition Place  43.640292 -79.437299
# 41                    Golden Mile, Clairlea, Oakridge  43.727841 -79.287622
# 42                                       Silver Hills  43.761222 -79.368382
# 44                     Commerce Court, Victoria Hotel  43.648095 -79.379025
# 45           North Park, Maple Leaf Park, Upwood Park  43.718690 -79.477534
# 50                                    Studio District  43.649585 -79.390683
# 66                  North Toronto West, Lawrence Park  43.653482 -79.383935
# 67                The Annex, North Midtown, Yorkville  43.670338 -79.407117
# 68                             Parkdale, Roncesvalles  43.640292 -79.437299
# 71                     University of Toronto, Harbord  43.663462 -79.397760
# 75          Kensington Market, Chinatown, Grange Park  43.655214 -79.402260
# 78  CN Tower, King and Spadina, Railway Lands, Har...  43.642564 -79.387087
# 83                Northwest, West Humber - Clairville  43.653482 -79.383935
# 85                        St. James Town, Cabbagetown  43.669403 -79.372704
# 86             First Canadian Place, Underground city  43.648768 -79.381692
# 88                               Church and Wellesley  43.665524 -79.383801
#
#     Cluster Label   1st Most Common Venue 2nd Most Common Venue  \
# 4               0             Coffee Shop   Japanese Restaurant
# 7               0          Clothing Store           Coffee Shop
# 9               0             Coffee Shop                  Café
# 13              0          Clothing Store           Coffee Shop
# 15              0             Coffee Shop            Restaurant
# 18              0             Coffee Shop                  Café
# 21              0             Coffee Shop                  Café
# 22              0       Korean Restaurant                  Café
# 27              0             Coffee Shop                   Gym
# 28              0                    Café                   Bar
# 30              0             Coffee Shop        Clothing Store
# 32              0             Coffee Shop                  Café
# 33              0             Coffee Shop                 Hotel
# 34              0                    Café                   Bar
# 36              0  Furniture / Home Store                  Café
# 39              0             Coffee Shop                 Hotel
# 40              0             Coffee Shop                  Café
# 41              0             Coffee Shop        Clothing Store
# 42              0  Furniture / Home Store           Coffee Shop
# 44              0             Coffee Shop                  Café
# 45              0          Clothing Store           Coffee Shop
# 50              0          Clothing Store           Coffee Shop
# 66              0             Coffee Shop                  Café
# 67              0                    Café    Italian Restaurant
# 68              0             Coffee Shop                  Café
# 71              0                    Café                Bakery
# 75              0                    Café                   Bar
# 78              0                   Hotel           Coffee Shop
# 83              0             Coffee Shop                  Café
# 85              0             Coffee Shop            Restaurant
# 86              0             Coffee Shop                 Hotel
# 88              0             Coffee Shop   Japanese Restaurant
#
#             3rd Most Common Venue          4th Most Common Venue  \
# 4                            Park               Sushi Restaurant
# 7            Fast Food Restaurant                 Baseball Field
# 9                       Gastropub            Japanese Restaurant
# 13           Fast Food Restaurant                 Baseball Field
# 15            Japanese Restaurant                           Café
# 18                     Restaurant             Seafood Restaurant
# 21                          Hotel            Japanese Restaurant
# 22                  Grocery Store                    Pizza Place
# 27                 Sandwich Place                           Park
# 28                    Coffee Shop                         Bakery
# 30                     Restaurant            Japanese Restaurant
# 32                     Restaurant                      Gastropub
# 33                           Café                           Park
# 34                     Restaurant                    Coffee Shop
# 36                    Coffee Shop                 Clothing Store
# 39                           Café            Japanese Restaurant
# 40                     Restaurant                            Bar
# 41           Fast Food Restaurant                 Hardware Store
# 42                         Arcade                           Bank
# 44                          Hotel            Japanese Restaurant
# 45         Furniture / Home Store                  Women's Store
# 50                           Café                 Sandwich Place
# 66                     Restaurant                      Gastropub
# 67              Korean Restaurant  Vegetarian / Vegan Restaurant
# 68                     Restaurant                            Bar
# 71                     Restaurant                      Bookstore
# 75  Vegetarian / Vegan Restaurant                    Coffee Shop
# 78                           Café                            Gym
# 83                     Restaurant                      Gastropub
# 85            Japanese Restaurant                           Café
# 86                           Café                        Theater
# 88                           Park                   Burger Joint
#
#     5th Most Common Venue          6th Most Common Venue  \
# 4             Art Gallery             Mexican Restaurant
# 7              Restaurant            Japanese Restaurant
# 9      Italian Restaurant                          Hotel
# 13             Restaurant            Japanese Restaurant
# 15                Gay Bar                          Diner
# 18    Japanese Restaurant                          Hotel
# 21              Gastropub             Italian Restaurant
# 22            Coffee Shop                   Cocktail Bar
# 27         Ice Cream Shop           Gym / Fitness Center
# 28                   Park                   Cocktail Bar
# 30                   Bank                       Pharmacy
# 32    Japanese Restaurant                          Hotel
# 33                    Gym                 Scenic Lookout
# 34                   Park  Vegetarian / Vegan Restaurant
# 36                   Bank                  Moving Target
# 39                Theater                   Concert Hall
# 40                 Bakery             Italian Restaurant
# 41          Women's Store         Furniture / Home Store
# 42         Discount Store            Japanese Restaurant
# 44             Restaurant                      Gastropub
# 45  Vietnamese Restaurant                    Gas Station
# 50            Yoga Studio                Thai Restaurant
# 66    Japanese Restaurant                          Hotel
# 67             Restaurant                         Bakery
# 68                 Bakery             Italian Restaurant
# 71            Coffee Shop             Italian Restaurant
# 75     Mexican Restaurant                     Taco Place
# 78                   Park             Seafood Restaurant
# 83    Japanese Restaurant                          Hotel
# 85                Gay Bar                          Diner
# 86             Restaurant                   Concert Hall
# 88       Sushi Restaurant                     Restaurant
#
#     7th Most Common Venue   8th Most Common Venue  \
# 4        Ramen Restaurant                    Café
# 7                    Bank               Juice Bar
# 9        Ramen Restaurant              Poke Place
# 13                   Bank               Juice Bar
# 15          Grocery Store               Gastropub
# 18              Gastropub                Creperie
# 21     Seafood Restaurant              Restaurant
# 22         Ice Cream Shop            Dessert Shop
# 27     Seafood Restaurant                     Pub
# 28  Vietnamese Restaurant    Caribbean Restaurant
# 30      Electronics Store          Sandwich Place
# 32       Sushi Restaurant  Furniture / Home Store
# 33                Brewery     Japanese Restaurant
# 34      Korean Restaurant               Gift Shop
# 36     Chinese Restaurant            Liquor Store
# 39             Restaurant           Deli / Bodega
# 40      Indian Restaurant      Tibetan Restaurant
# 41         Sandwich Place          Shopping Plaza
# 42          Train Station              Restaurant
# 44           Concert Hall      Seafood Restaurant
# 45           Carpet Store              Shoe Store
# 50    American Restaurant             Art Gallery
# 66       Sushi Restaurant  Furniture / Home Store
# 67          Grocery Store             Coffee Shop
# 68      Indian Restaurant      Tibetan Restaurant
# 71                   Park                Beer Bar
# 75           Dessert Shop            Cocktail Bar
# 78         Scenic Lookout                   Plaza
# 83       Sushi Restaurant  Furniture / Home Store
# 85          Grocery Store               Gastropub
# 86    Japanese Restaurant           Deli / Bodega
# 88            Yoga Studio                    Café
#
#           9th Most Common Venue         10th Most Common Venue
# 4                  Dessert Shop                   Burger Joint
# 7           Sporting Goods Shop                     Food Court
# 9                         Plaza      Middle Eastern Restaurant
# 13          Sporting Goods Shop                     Food Court
# 15              Thai Restaurant                            Pub
# 18                 Cocktail Bar             Italian Restaurant
# 21             Ramen Restaurant                          Plaza
# 22  Eastern European Restaurant                     Restaurant
# 27                Movie Theater             Mexican Restaurant
# 28                     Beer Bar                          Diner
# 30                 Liquor Store                     Food Court
# 32                     Tea Room                        Theater
# 33                   Restaurant                    Music Venue
# 34            French Restaurant                   Cocktail Bar
# 36         Fast Food Restaurant                            Spa
# 39               Cosmetics Shop                           Park
# 40                     Pharmacy                           Park
# 41                  Supermarket                           Bank
# 42            Food & Drink Shop                            Pub
# 44                       Bakery                Thai Restaurant
# 45         Fast Food Restaurant             Chinese Restaurant
# 50                       Bakery               Baseball Stadium
# 66                     Tea Room                        Theater
# 67           Mexican Restaurant                            Bar
# 68                     Pharmacy                           Park
# 71                     Boutique  Vegetarian / Vegan Restaurant
# 75                  Art Gallery                         Bakery
# 78                  Pizza Place            Japanese Restaurant
# 83                     Tea Room                        Theater
# 85              Thai Restaurant                            Pub
# 86           Seafood Restaurant                          Plaza
# 88                        Diner                   Dance Studio

# %%
cluster1=df.loc[df['Cluster Label'] == 1, df.columns[list(range(0, df.shape[1]))]]
cluster1
# Out:
#    Postal Code           Borough  \
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 5          M9A         Etobicoke
# 14         M4C         East York
# 20         M4G         East York
# 26         M4H         East York
# 37         M3K        North York
# 38         M4K      East Toronto
# 48         M2M        North York
# 51         M5M        North York
# 52         M2N        North York
# 54         M4N   Central Toronto
# 55         M5N   Central Toronto
# 56         M6N              York
# 59         M2P        North York
# 60         M4P   Central Toronto
# 61         M5P   Central Toronto
# 62         M6P      West Toronto
# 65         M2R        North York
# 70         M4S   Central Toronto
# 72         M6S      West Toronto
# 74         M4T   Central Toronto
# 77         M4V   Central Toronto
# 79         M8V         Etobicoke
# 82         M4W  Downtown Toronto
# 87         M8X         Etobicoke
# 89         M8Z         Etobicoke
# 91         M8Y         Etobicoke
# 92         M6C        North York
# 93         M4E         East York
# 94         M1N       Scarborough
# 95         M5R   Central Toronto
# 98         M4C         East York
#
#                                          Neighborhood   latitude  longitude  \
# 2                           Regent Park, Harbourfront  43.660706 -79.360457
# 3                    Lawrence Manor, Lawrence Heights  43.722079 -79.437507
# 5             Islington Avenue, Humber Valley Village  43.679484 -79.538909
# 14                                   Woodbine Heights  43.699930 -79.319132
# 20                                            Leaside  43.704798 -79.368090
# 26                                   Thorncliffe Park  43.704553 -79.345407
# 37                                           Ancaster  43.733449 -79.465647
# 38                       The Danforth West, Riverdale  43.686433 -79.300356
# 48                                        Newtonbrook  43.793886 -79.425679
# 51                  Bedford Park, Lawrence Manor East  43.737388 -79.410925
# 52                                    Willowdale East  43.761509 -79.410923
# 54                                      Lawrence Park  43.729199 -79.403253
# 55                                           Roselawn  43.699456 -79.454616
# 56                      Runnymede, The Junction North  43.651703 -79.475998
# 59                                    York Mills West  43.744039 -79.406657
# 60                                   Davisville North  43.697936 -79.397291
# 61    Forest Hill North & West, Forest Hill Road Park  43.701028 -79.425600
# 62                      High Park, The Junction South  43.653867 -79.466864
# 65                                    Willowdale West  43.761509 -79.410923
# 70                                         Davisville  43.697936 -79.397291
# 72                                 Runnymede, Swansea  43.651703 -79.475998
# 74                        Moore Park, Summerhill East  43.690388 -79.383297
# 77  Summerhill West, Rathnelly, South Hill, Forest...  43.681678 -79.390504
# 79       New Toronto, Mimico South, Humber Bay Shores  43.600763 -79.505264
# 82                                           Rosedale  43.678356 -79.380746
# 87      The Kingsway, Montgomery Road, Old Mill North  43.647381 -79.511333
# 89  Mimico NW, The Queensway West, South of Bloor,...  43.616677 -79.496805
# 91                           The Queensway-Humber Bay  43.626324 -79.502766
# 92                       Vaughan, Cedervale ,Humewood  43.682857 -79.419540
# 93                                            Beaches  43.671024 -79.296712
# 94                                        Birch Cliff  43.691805 -79.264494
# 95                                          Davenport  43.671545 -79.448322
# 98                                   Toronto Danforth  43.678944 -79.344860
#
#     Cluster Label   1st Most Common Venue 2nd Most Common Venue  \
# 2               1             Coffee Shop            Restaurant
# 3               1             Coffee Shop         Grocery Store
# 5               1                    Bank           Coffee Shop
# 14              1             Pizza Place              Pharmacy
# 20              1                  Bakery         Grocery Store
# 26              1       Indian Restaurant                  Bank
# 37              1                    Park    Turkish Restaurant
# 38              1             Coffee Shop           Pizza Place
# 48              1       Korean Restaurant           Coffee Shop
# 51              1             Coffee Shop      Sushi Restaurant
# 52              1             Coffee Shop                  Bank
# 54              1        Sushi Restaurant                Bakery
# 55              1  Furniture / Home Store           Coffee Shop
# 56              1             Coffee Shop                  Café
# 59              1             Coffee Shop            Restaurant
# 60              1             Coffee Shop    Italian Restaurant
# 61              1             Coffee Shop                 Trail
# 62              1             Coffee Shop           Pizza Place
# 65              1             Coffee Shop                  Bank
# 70              1             Coffee Shop    Italian Restaurant
# 72              1             Coffee Shop                  Café
# 74              1             Coffee Shop                  Park
# 77              1             Coffee Shop    Italian Restaurant
# 79              1                    Park           Pizza Place
# 82              1             Coffee Shop    Italian Restaurant
# 87              1             Coffee Shop                   Pub
# 89              1          Breakfast Spot     Indian Restaurant
# 91              1              Restaurant    Italian Restaurant
# 92              1                    Café           Coffee Shop
# 93              1                     Pub           Coffee Shop
# 94              1                    Park       Thai Restaurant
# 95              1                    Café    Italian Restaurant
# 98              1        Greek Restaurant                  Café
#
#         3rd Most Common Venue      4th Most Common Venue  \
# 2                      Bakery                       Café
# 3                 Pizza Place       Fast Food Restaurant
# 5           Electronics Store                 Beer Store
# 14                       Park            Thai Restaurant
# 20                Coffee Shop                 Restaurant
# 26         Turkish Restaurant                Coffee Shop
# 37                Coffee Shop  Latin American Restaurant
# 38                       Park                   Bus Line
# 48  Middle Eastern Restaurant                       Café
# 51             Sandwich Place        Japanese Restaurant
# 52        Japanese Restaurant              Grocery Store
# 54         Italian Restaurant                Coffee Shop
# 55                       Park                Pizza Place
# 56                        Pub                Pizza Place
# 59          Convenience Store               Intersection
# 60           Sushi Restaurant                 Restaurant
# 61                Pizza Place         Italian Restaurant
# 62                       Park                       Café
# 65        Japanese Restaurant              Grocery Store
# 70           Sushi Restaurant                 Restaurant
# 72                        Pub                Pizza Place
# 74         Italian Restaurant              Grocery Store
# 77                       Café                       Park
# 79        Fried Chicken Joint                Supermarket
# 82              Grocery Store                       Park
# 87                 Restaurant             Breakfast Spot
# 89                       Park                       Bank
# 91             Ice Cream Shop                  BBQ Joint
# 92         Italian Restaurant                       Park
# 93                      Beach        Japanese Restaurant
# 94                 Restaurant            College Stadium
# 95                Coffee Shop                       Park
# 98                Coffee Shop         Italian Restaurant
#
#    5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 2                   Park            Thai Restaurant                   Pub
# 3             Bagel Shop                   Pharmacy                  Bank
# 5          Shopping Mall                Golf Course                  Café
# 14                   Pub                        Spa          Skating Rink
# 20      Sushi Restaurant        Sporting Goods Shop       Thai Restaurant
# 26     Afghan Restaurant                    Brewery  Fast Food Restaurant
# 37     Electronics Store         Italian Restaurant    Chinese Restaurant
# 38        Ice Cream Shop           Sushi Restaurant        Sandwich Place
# 48            Restaurant             Sandwich Place           Pizza Place
# 51    Italian Restaurant                        Pub            Restaurant
# 52        Sandwich Place       Fast Food Restaurant      Ramen Restaurant
# 54        Cosmetics Shop                Pizza Place                  Bank
# 55              Pharmacy             Sandwich Place                  Bank
# 56      Sushi Restaurant         Italian Restaurant                Bakery
# 59      Business Service                 Food Court     French Restaurant
# 60                  Café                        Gym                  Park
# 61                  Bank  Middle Eastern Restaurant    Mexican Restaurant
# 62                   Pub                        Bar       Thai Restaurant
# 65        Sandwich Place       Fast Food Restaurant      Ramen Restaurant
# 70                  Café                        Gym                  Park
# 72      Sushi Restaurant         Italian Restaurant                Bakery
# 74                   Gym             Sandwich Place       Thai Restaurant
# 77      Sushi Restaurant             Sandwich Place                   Pub
# 79          Liquor Store                     Bakery                  Café
# 82                  Bank                     Office                   Gym
# 87    Italian Restaurant               Dessert Shop      Sushi Restaurant
# 89         Grocery Store          Convenience Store    Italian Restaurant
# 91      Sushi Restaurant                Pizza Place           Coffee Shop
# 92     Indian Restaurant                 Restaurant                  Bank
# 93        Breakfast Spot                Pizza Place                   Bar
# 94                 Diner                       Café                   Gym
# 95                Bakery           Sushi Restaurant  Brazilian Restaurant
# 98                  Park                 Restaurant             Bookstore
#
#    8th Most Common Venue      9th Most Common Venue 10th Most Common Venue
# 2              Gastropub             Breakfast Spot                  Diner
# 3               Bus Stop             Discount Store       Sushi Restaurant
# 5           Liquor Store              Grocery Store         Sandwich Place
# 14        Breakfast Spot               Liquor Store                   Café
# 20     Indian Restaurant             Sandwich Place             Baby Store
# 26           Pizza Place        Fried Chicken Joint                    Gym
# 37     Other Repair Shop               Intersection                   Café
# 38         Grocery Store                Flower Shop       Asian Restaurant
# 48          Dessert Shop        Rental Car Location          Grocery Store
# 51                Bakery                   Pharmacy   Fast Food Restaurant
# 52           Pizza Place  Middle Eastern Restaurant       Sushi Restaurant
# 54      Asian Restaurant              Grocery Store                    Pub
# 55        Discount Store         Italian Restaurant                 Bakery
# 56    Falafel Restaurant             Baseball Field                   Bank
# 59        Sandwich Place                       Park            Golf Course
# 60             Gastropub                        Pub   Fast Food Restaurant
# 61          Skating Rink                       Café     Frozen Yogurt Shop
# 62                Bakery          Convenience Store         Baseball Field
# 65           Pizza Place  Middle Eastern Restaurant       Sushi Restaurant
# 70             Gastropub                        Pub   Fast Food Restaurant
# 72    Falafel Restaurant             Baseball Field                   Bank
# 74                  Café                  Gastropub             Bagel Shop
# 77                  Bank          French Restaurant        Thai Restaurant
# 79    Italian Restaurant                 Restaurant           Dessert Shop
# 82     Indian Restaurant        Japanese Restaurant              Juice Bar
# 87                  Bank                Pizza Place   Fast Food Restaurant
# 89               Brewery           Storage Facility                    Bar
# 91       Thai Restaurant                     Bakery                    Bar
# 92        Ice Cream Shop                Pizza Place         Sandwich Place
# 93                  Park                     Bakery               Tea Room
# 94          Skating Rink      General Entertainment       Doner Restaurant
# 95                   Bar                       Bank  Portuguese Restaurant
# 98           Pizza Place                       Bank   Fast Food Restaurant
